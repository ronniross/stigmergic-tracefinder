# %%
# exact phrase matching (arXiv-stigmergic-trace-finder)
import subprocess
import sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "arxiv"])

import arxiv
import time
from IPython.display import Markdown, display

# --- Search Parameters ---
# Tip: "animal communication" searches the exact phrase.
# If you want more results (e.g., 600+), use "animal, communication"
# to search for papers containing both words anywhere in the text.
keywords_input = "animal communication"
batch_size = 30
# -------------------------

def search_arxiv_in_batches():
    # Clean up keywords, strip extra spaces, and force LOWERCASE to make it case-insensitive
    keywords = [kw.strip().lower() for kw in keywords_input.split(",") if kw.strip()]

    if not keywords:
        print("Please provide at least one keyword.")
        return

    # Build the query
    query = " AND ".join([f'all:"{kw}"' for kw in keywords])
    print(f"Searching arXiv for: {query}...\n")

    # Set up the arXiv client and search
    client = arxiv.Client()
    search = arxiv.Search(
        query=query,
        max_results=10000, # High limit to get all available papers
        sort_by=arxiv.SortCriterion.SubmittedDate,
        sort_order=arxiv.SortOrder.Descending
    )

    results_generator = client.results(search)

    batch_number = 1
    total_fetched = 0
    all_results = [] # Store everything here to merge at the end

    while True:
        # Fetch the next batch
        current_batch = []
        try:
            for _ in range(batch_size):
                current_batch.append(next(results_generator))
        except StopIteration:
            pass # Reached the end of available API results

        if not current_batch:
            if total_fetched == 0:
                print("No papers found for those keywords.")
            break

        total_fetched += len(current_batch)
        all_results.extend(current_batch) # Save to master list

        # --- Print Titles and Year for this batch ---
        print(f"\n--- BATCH {batch_number} (Results {(batch_number-1)*batch_size + 1} to {total_fetched}) ---")
        for i, res in enumerate(current_batch, 1):
            overall_index = (batch_number - 1) * batch_size + i
            year = res.published.year
            print(f"{overall_index}. {res.title} ({year})")

        # Check if we hit the end of the results
        if len(current_batch) < batch_size:
            print("\n" + "="*70)
            print("--- Reached the end of available results. ---")
            break

        print("\nWaiting 5 seconds before fetching the next batch...")
        time.sleep(5)
        batch_number += 1

    # --- FINAL STEP: Merge all batches into one Markdown list ---
    if all_results:
        print("\nGenerating final merged clickable list...\n")

        md_content = f"### All Clickable Results ({len(all_results)} total papers found)\n\n"
        for res in all_results:
            # Extract author names
            authors = ", ".join([author.name for author in res.authors])
            # Extract year
            year = res.published.year
            # Format: * [Title](URL) (Year) - *Authors*
            md_content += f"* **[{res.title}]({res.entry_id})** ({year}) <br> 👤 *{authors}*\n\n"

        # Display the complete merged markdown
        display(Markdown(md_content))

# Run the function
search_arxiv_in_batches()
# Out:
# Searching arXiv for: all:"animal communication"...
#
#
# --- BATCH 1 (Results 1 to 30) ---
# 1. chatter: a Python library for applying information theory and AI/ML models to animal communication (2025)
# 2. What Needs to be Known in Order to Perform a Meaningful Scientific Comparison Between Animal Communications and Human Spoken Language (2025)
# 3. Perch 2.0 transfers 'whale' to underwater tasks (2025)
# 4. Associative Syntax and Maximal Repetitions reveal context-dependent complexity in fruit bat communication (2025)
# 5. Towards Leveraging Sequential Structure in Animal Vocalizations (2025)
# 6. The Double Contingency Problem: AI Recursion and the Limits of Interspecies Understanding (2025)
# 7. On Non-interactive Evaluation of Animal Communication Translators (2025)
# 8. Identifying birdsong syllables without labelled data (2025)
# 9. A universal animal communication tempo resonates with the receiver's brain (2025)
# 10. Controllable Single-shot Animation Blending with Temporal Conditioning (2025)
# 11. LLMs vs. Chinese Anime Enthusiasts: A Comparative Study on Emotionally Supportive Role-Playing (2025)
# 12. AnimeDL-2M: Million-Scale AI-Generated Anime Image Detection and Localization in Diffusion Era (2025)
# 13. Visual Theory of Mind Enables the Invention of Proto-Writing (2025)
# 14. Unattended field measurement of bird source level (2024)
# 15. SMPLOlympics: Sports Environments for Physically Simulated Humanoids (2024)
# 16. Holon: a cybernetic interface for bio-semiotics (2024)
# 17. DanceCamera3D: 3D Camera Movement Synthesis with Music and Dance (2024)
# 18. Not your private tête-à-tête: leveraging the power of higher-order networks to study animal communication (2023)
# 19. Large language models and (non-)linguistic recursion (2023)
# 20. Approaching an unknown communication system by latent space exploration and causal inference (2023)
# 21. A Theory of Unsupervised Translation Motivated by Understanding Animal Communication (2022)
# 22. Bayesian Multi-Species N-Mixture Models for Unmarked Animal Communities (2021)
# 23. A functional skeleton transfer (2021)
# 24. Cetacean Translation Initiative: a roadmap to deciphering the communication of sperm whales (2021)
# 25. Low-Bandwidth Communication Emerges Naturally in Multi-Agent Learning Systems (2020)
# 26. Bayesian Context Trees: Modelling and exact inference for discrete time series (2020)
# 27. Spatial memory and taxis-driven pattern formation in model ecosystems (2019)
# 28. Formal models of Structure Building in Music, Language and Animal Songs (2019)
# 29. Dancing Honey bee Robot Elicits Dance-Following and Recruits Foragers (2018)
# 30. Automatic detection and decoding of honey bee waggle dances (2017)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 2 (Results 31 to 40) ---
# 31. Community interactions determine role of species in parasite spread amplification: the ecomultiplex network model (2017)
# 32. Fast Chirplet Transform to Enhance CNN Machine Listening - Validation on Animal calls and Speech (2016)
# 33. Emergence of linguistic laws in human voice (2016)
# 34. Rendering-as-a-Service: Taxonomy and Comparison (2015)
# 35. Collapse of an ecological network in Ancient Egypt (2014)
# 36. Step selection techniques uncover the environmental predictors of space use patterns in flocks of Amazonian birds (2014)
# 37. Complexity in animal communication: Estimating the size of N-Gram structures (2013)
# 38. The Biological Origin of Linguistic Diversity (2013)
# 39. Monitoring wild animal communities with arrays of motion sensitive camera traps (2010)
# 40. A simplex model for layered niche networks (2006)
#
# ======================================================================
# --- Reached the end of available results. ---
#
# Generating final merged clickable list...
# ### All Clickable Results (40 total papers found)
#
# * **[chatter: a Python library for applying information theory and AI/ML models to animal communication](http://arxiv.org/abs/2512.17935v1)** (2025) <br> 👤 *Mason Youngblood*
#
# * **[What Needs to be Known in Order to Perform a Meaningful Scientific Comparison Between Animal Communications and Human Spoken Language](http://arxiv.org/abs/2512.06890v1)** (2025) <br> 👤 *Roger K. Moore*
#
# * **[Perch 2.0 transfers 'whale' to underwater tasks](http://arxiv.org/abs/2512.03219v1)** (2025) <br> 👤 *Andrea Burns, Lauren Harrell, Bart van Merriënboer, Vincent Dumoulin, Jenny Hamer, Tom Denton*
#
# * **[Associative Syntax and Maximal Repetitions reveal context-dependent complexity in fruit bat communication](http://arxiv.org/abs/2512.01033v1)** (2025) <br> 👤 *Luigi Assom*
#
# * **[Towards Leveraging Sequential Structure in Animal Vocalizations](http://arxiv.org/abs/2511.10190v1)** (2025) <br> 👤 *Eklavya Sarkar, Mathew Magimai. -Doss*
#
# * **[The Double Contingency Problem: AI Recursion and the Limits of Interspecies Understanding](http://arxiv.org/abs/2511.08927v1)** (2025) <br> 👤 *Graham L. Bishop*
#
# * **[On Non-interactive Evaluation of Animal Communication Translators](http://arxiv.org/abs/2510.15768v1)** (2025) <br> 👤 *Orr Paradise, David F. Gruber, Adam Tauman Kalai*
#
# * **[Identifying birdsong syllables without labelled data](http://arxiv.org/abs/2509.18412v1)** (2025) <br> 👤 *Mélisande Teng, Julien Boussard, David Rolnick, Hugo Larochelle*
#
# * **[A universal animal communication tempo resonates with the receiver's brain](http://arxiv.org/abs/2508.21530v1)** (2025) <br> 👤 *Guy Amichay, Vijay Balasubramanian, Daniel M. Abrams*
#
# * **[Controllable Single-shot Animation Blending with Temporal Conditioning](http://arxiv.org/abs/2508.18525v1)** (2025) <br> 👤 *Eleni Tselepi, Spyridon Thermos, Gerasimos Potamianos*
#
# * **[LLMs vs. Chinese Anime Enthusiasts: A Comparative Study on Emotionally Supportive Role-Playing](http://arxiv.org/abs/2508.06388v1)** (2025) <br> 👤 *Lanlan Qiu, Xiao Pu, Yeqi Feng, Tianxing He*
#
# * **[AnimeDL-2M: Million-Scale AI-Generated Anime Image Detection and Localization in Diffusion Era](http://arxiv.org/abs/2504.11015v2)** (2025) <br> 👤 *Chenyang Zhu, Xing Zhang, Yuyang Sun, Ching-Chun Chang, Isao Echizen*
#
# * **[Visual Theory of Mind Enables the Invention of Proto-Writing](http://arxiv.org/abs/2502.01568v5)** (2025) <br> 👤 *Benjamin A. Spiegel, Lucas Gelfond, George Konidaris*
#
# * **[Unattended field measurement of bird source level](http://arxiv.org/abs/2409.10957v1)** (2024) <br> 👤 *Guillaume Dutilleux*
#
# * **[SMPLOlympics: Sports Environments for Physically Simulated Humanoids](http://arxiv.org/abs/2407.00187v1)** (2024) <br> 👤 *Zhengyi Luo, Jiashun Wang, Kangni Liu, Haotian Zhang, Chen Tessler, Jingbo Wang, Ye Yuan, Jinkun Cao, Zihui Lin, Fengyi Wang, Jessica Hodgins, Kris Kitani*
#
# * **[Holon: a cybernetic interface for bio-semiotics](http://arxiv.org/abs/2404.03894v1)** (2024) <br> 👤 *Jon McCormack, Elliott Wilson*
#
# * **[DanceCamera3D: 3D Camera Movement Synthesis with Music and Dance](http://arxiv.org/abs/2403.13667v1)** (2024) <br> 👤 *Zixuan Wang, Jia Jia, Shikun Sun, Haozhe Wu, Rong Han, Zhenyu Li, Di Tang, Jiaqing Zhou, Jiebo Luo*
#
# * **[Not your private tête-à-tête: leveraging the power of higher-order networks to study animal communication](http://arxiv.org/abs/2309.03783v2)** (2023) <br> 👤 *Iacopo Iacopini, Jennifer R Foote, Nina H Fefferman, Elizabeth P Derryberry, Matthew J Silk*
#
# * **[Large language models and (non-)linguistic recursion](http://arxiv.org/abs/2306.07195v1)** (2023) <br> 👤 *Maksymilian Dąbkowski, Gašper Beguš*
#
# * **[Approaching an unknown communication system by latent space exploration and causal inference](http://arxiv.org/abs/2303.10931v2)** (2023) <br> 👤 *Gašper Beguš, Andrej Leban, Shane Gero*
#
# * **[A Theory of Unsupervised Translation Motivated by Understanding Animal Communication](http://arxiv.org/abs/2211.11081v2)** (2022) <br> 👤 *Shafi Goldwasser, David F. Gruber, Adam Tauman Kalai, Orr Paradise*
#
# * **[Bayesian Multi-Species N-Mixture Models for Unmarked Animal Communities](http://arxiv.org/abs/2109.14966v2)** (2021) <br> 👤 *Niamh Mimnagh, Andrew Parnell, Estevao Prado, Rafael de Andrade Moral*
#
# * **[A functional skeleton transfer](http://arxiv.org/abs/2108.12041v1)** (2021) <br> 👤 *Pietro Musoni, Riccardo Marin, Simone Melzi, Umberto Castellani*
#
# * **[Cetacean Translation Initiative: a roadmap to deciphering the communication of sperm whales](http://arxiv.org/abs/2104.08614v1)** (2021) <br> 👤 *Jacob Andreas, Gašper Beguš, Michael M. Bronstein, Roee Diamant, Denley Delaney, Shane Gero, Shafi Goldwasser, David F. Gruber, Sarah de Haas, Peter Malkin, Roger Payne, Giovanni Petri, Daniela Rus, Pratyusha Sharma, Dan Tchernov, Pernille Tønnesen, Antonio Torralba, Daniel Vogt, Robert J. Wood*
#
# * **[Low-Bandwidth Communication Emerges Naturally in Multi-Agent Learning Systems](http://arxiv.org/abs/2011.14890v2)** (2020) <br> 👤 *Niko A. Grupen, Daniel D. Lee, Bart Selman*
#
# * **[Bayesian Context Trees: Modelling and exact inference for discrete time series](http://arxiv.org/abs/2007.14900v3)** (2020) <br> 👤 *Ioannis Kontoyiannis, Lambros Mertzanis, Athina Panotopoulou, Ioannis Papageorgiou, Maria Skoularidou*
#
# * **[Spatial memory and taxis-driven pattern formation in model ecosystems](http://arxiv.org/abs/1903.05381v2)** (2019) <br> 👤 *Jonathan R. Potts, Mark A. Lewis*
#
# * **[Formal models of Structure Building in Music, Language and Animal Songs](http://arxiv.org/abs/1901.05180v1)** (2019) <br> 👤 *Willem Zuidema, Dieuwke Hupkes, Geraint Wiggins, Constance Scharff, Martin Rohrmeier*
#
# * **[Dancing Honey bee Robot Elicits Dance-Following and Recruits Foragers](http://arxiv.org/abs/1803.07126v1)** (2018) <br> 👤 *Tim Landgraf, David Bierbach, Andreas Kirbach, Rachel Cusing, Michael Oertel, Konstantin Lehmann, Uwe Greggers, Randolf Menzel, Raúl Rojas*
#
# * **[Automatic detection and decoding of honey bee waggle dances](http://arxiv.org/abs/1708.06590v3)** (2017) <br> 👤 *Fernando Wario, Benjamin Wild, Raúl Rojas, Tim Landgraf*
#
# * **[Community interactions determine role of species in parasite spread amplification: the ecomultiplex network model](http://arxiv.org/abs/1706.05121v1)** (2017) <br> 👤 *Massimo Stella, Sanja Selakovic, Alberto Antonioni, Cecilia S. Andreazzi*
#
# * **[Fast Chirplet Transform to Enhance CNN Machine Listening - Validation on Animal calls and Speech](http://arxiv.org/abs/1611.08749v2)** (2016) <br> 👤 *Herve Glotin, Julien Ricard, Randall Balestriero*
#
# * **[Emergence of linguistic laws in human voice](http://arxiv.org/abs/1610.02736v1)** (2016) <br> 👤 *Ivan Gonzalez Torre, Bartolo Luque, Lucas Lacasa, Jordi Luque, Antoni Hernandez-Fernandez*
#
# * **[Rendering-as-a-Service: Taxonomy and Comparison](http://arxiv.org/abs/1505.06543v1)** (2015) <br> 👤 *Ruby Annette, Aisha Banu, Subash Chandran*
#
# * **[Collapse of an ecological network in Ancient Egypt](http://arxiv.org/abs/1409.7006v1)** (2014) <br> 👤 *Justin D. Yeakel, Mathias M. Pires, Lars Rudolf, Nathaniel J. Dominy, Paul L. Koch, Paulo R. Guimarães, Thilo Gross*
#
# * **[Step selection techniques uncover the environmental predictors of space use patterns in flocks of Amazonian birds](http://arxiv.org/abs/1403.6869v3)** (2014) <br> 👤 *Jonathan R. Potts, Karl Mokross, Philip C Stouffer, Mark A. Lewis*
#
# * **[Complexity in animal communication: Estimating the size of N-Gram structures](http://arxiv.org/abs/1308.3616v2)** (2013) <br> 👤 *Reginald D. Smith*
#
# * **[The Biological Origin of Linguistic Diversity](http://arxiv.org/abs/1302.2937v1)** (2013) <br> 👤 *Andrea Baronchelli, Nick Chater, Romualdo Pastor-Satorras, Morten H. Christiansen*
#
# * **[Monitoring wild animal communities with arrays of motion sensitive camera traps](http://arxiv.org/abs/1009.5718v1)** (2010) <br> 👤 *Roland Kays, Sameer Tilak, Bart Kranstauber, Patrick A. Jansen, Chris Carbone, Marcus J. Rowcliffe, Tony Fountain, Jay Eggert, Zhihai He*
#
# * **[A simplex model for layered niche networks](http://arxiv.org/abs/physics/0603068v2)** (2006) <br> 👤 *P. Fraundorf*

# %%
# dynamic phrase matching (arXiv-stigmergic-trace-finder)
import subprocess
import sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "arxiv"])

import arxiv
import time
from IPython.display import Markdown, display

# --- Search Parameters ---
keywords_input = "animal communication"
batch_size = 30
# -------------------------

def search_arxiv_in_batches():
    # Replace commas and underscores with spaces, then split into individual words
    # This stops the API from doing strict "exact phrase" matches and instead acts like the website
    raw_words = keywords_input.replace(",", " ").replace("_", " ").split()
    words = [w.strip().lower() for w in raw_words if w.strip()]

    if not words:
        print("Please provide at least one keyword.")
        return

    # Build the query: e.g., all:animal AND all:communication
    query = " AND ".join([f"all:{w}" for w in words])
    print(f"Searching arXiv broadly for: {query}...\n")

    # Set up the arXiv client and search
    client = arxiv.Client()
    search = arxiv.Search(
        query=query,
        max_results=10000, # High limit to get all available papers
        sort_by=arxiv.SortCriterion.SubmittedDate,
        sort_order=arxiv.SortOrder.Descending
    )

    results_generator = client.results(search)

    batch_number = 1
    total_fetched = 0
    all_results = [] # Store everything here to merge at the end

    while True:
        # Fetch the next batch
        current_batch = []
        try:
            for _ in range(batch_size):
                current_batch.append(next(results_generator))
        except StopIteration:
            pass # Reached the end of available API results

        if not current_batch:
            if total_fetched == 0:
                print("No papers found for those keywords.")
            break

        total_fetched += len(current_batch)
        all_results.extend(current_batch) # Save to master list

        # --- Print Titles and Year for this batch ---
        print(f"\n--- BATCH {batch_number} (Results {(batch_number-1)*batch_size + 1} to {total_fetched}) ---")
        for i, res in enumerate(current_batch, 1):
            overall_index = (batch_number - 1) * batch_size + i
            year = res.published.year
            print(f"{overall_index}. {res.title} ({year})")

        # Check if we hit the end of the results
        if len(current_batch) < batch_size:
            print("\n" + "="*70)
            print("--- Reached the end of available results. ---")
            break

        print("\nWaiting 5 seconds before fetching the next batch...")
        time.sleep(5)
        batch_number += 1

    # --- FINAL STEP: Merge all batches into one Markdown list ---
    if all_results:
        print("\n" + "="*70)
        print(f"Generating final merged clickable list for all {len(all_results)} papers...\n")

        md_content = f"### All Clickable Results ({len(all_results)} total papers found)\n\n"
        for res in all_results:
            # Extract author names
            authors = ", ".join([author.name for author in res.authors])
            # Extract year
            year = res.published.year
            # Format: * [Title](URL) (Year) - *Authors*
            md_content += f"* **[{res.title}]({res.entry_id})** ({year}) <br> 👤 *{authors}*\n\n"

        # Display the complete merged markdown
        display(Markdown(md_content))

# Run the function
search_arxiv_in_batches()
# Out:
# Searching arXiv broadly for: all:animal AND all:communication...
#
#
# --- BATCH 1 (Results 1 to 30) ---
# 1. SPRITETOMESH: Automatic Mesh Generation for 2D Skeletal Animation Using Learned Segmentation and Contour-Aware Vertex Placement (2026)
# 2. Kami of the Commons: Towards Designing Agentic AI to Steward the Commons (2026)
# 3. Human-Like Gaze Behavior in Social Robots: A Deep Learning Approach Integrating Human and Non-Human Stimuli (2026)
# 4. PRISM-XR: Empowering Privacy-Aware XR Collaboration with Multimodal Large Language Models (2026)
# 5. ALIVE: Animate Your World with Lifelike Audio-Video Generation (2026)
# 6. Distributed Omniscient Observers for Multi-Agent Systems: Design and Applications (2026)
# 7. Shaping Expressiveness in Robotics: The Role of Design Tools in Crafting Embodied Robot Movements (2026)
# 8. PrevizWhiz: Combining Rough 3D Scenes and 2D Video to Guide Generative Video Previsualization (2026)
# 9. The First Mass Protest on Threads: Multimodal Mobilization and AI-Generated Visuals in Taiwan's Bluebird Movement (2026)
# 10. Rheologically tuned diffusion modulates quorum sensing in Vibrio fischeri (2026)
# 11. Embryonic Exposure to VPA Influences Chick Vocalisations: A Computational Study (2026)
# 12. REFA: Real-time Egocentric Facial Animations for Virtual Reality (2026)
# 13. Lensing Capillary Waves with a Meniscus (2026)
# 14. APOLLO Blender: A Robotics Library for Visualization and Animation in Blender (2025)
# 15. chatter: a Python library for applying information theory and AI/ML models to animal communication (2025)
# 16. What Needs to be Known in Order to Perform a Meaningful Scientific Comparison Between Animal Communications and Human Spoken Language (2025)
# 17. Perch 2.0 transfers 'whale' to underwater tasks (2025)
# 18. EvalTalker: Learning to Evaluate Real-Portrait-Driven Multi-Subject Talking Humans (2025)
# 19. Associative Syntax and Maximal Repetitions reveal context-dependent complexity in fruit bat communication (2025)
# 20. Astro-Animation -- How Artists and Scientists Envision the Universe (2025)
# 21. AI Deception: Risks, Dynamics, and Controls (2025)
# 22. Assessing Gaze and Pointing: Human Cue Interpretation by Indian Free-Ranging Dogs in a Food Retrieval Task (2025)
# 23. IsharaKotha: A Comprehensive Avatar-based Bangla Sign Language Corpus (2025)
# 24. TailCue: Exploring Animal-inspired Robotic Tail for Automated Vehicles Interaction (2025)
# 25. EmoVid: A Multimodal Emotion Video Dataset for Emotion-Centric Video Understanding and Generation (2025)
# 26. Towards Leveraging Sequential Structure in Animal Vocalizations (2025)
# 27. The Double Contingency Problem: AI Recursion and the Limits of Interspecies Understanding (2025)
# 28. Understanding Electro-communication and Electro-sensing in Weakly Electric Fish using Multi-Agent Deep Reinforcement Learning (2025)
# 29. oboro: Text-to-Image Synthesis on Limited Data using Flow-based Diffusion Transformer with MMH Attention (2025)
# 30. Active Learning for Animal Re-Identification with Ambiguity-Aware Sampling (2025)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 2 (Results 31 to 60) ---
# 31. Laugh, Relate, Engage: Stylized Comment Generation for Short Videos (2025)
# 32. 4-Doodle: Text to 3D Sketches that Move! (2025)
# 33. Revising Second Order Terms in Deep Animation Video Coding (2025)
# 34. On Non-interactive Evaluation of Animal Communication Translators (2025)
# 35. Big Data Approaches to Bovine Bioacoustics: A FAIR-Compliant Dataset and Scalable ML Framework for Precision Livestock Welfare (2025)
# 36. DHQA-4D: Perceptual Quality Assessment of Dynamic 4D Digital Human (2025)
# 37. Cross-Breed Pig Identification Using Auricular Vein Pattern Recognition: A Machine Learning Approach for Small-Scale Farming Applications (2025)
# 38. Audio Driven Real-Time Facial Animation for Social Telepresence (2025)
# 39. KAMERA: Enhancing Aerial Surveys of Ice-associated Seals in Arctic Environments (2025)
# 40. Identifying birdsong syllables without labelled data (2025)
# 41. Model-free algorithms for fast node clustering in SBM type graphs and application to social role inference in animals (2025)
# 42. Investigating the Effect of LED Signals and Emotional Displays in Human-Robot Shared Workspaces (2025)
# 43. Osu2MIR: Beat Tracking Dataset Derived From Osu! Data (2025)
# 44. VideoAgent: Personalized Synthesis of Scientific Videos (2025)
# 45. Using the Pepper Robot to Support Sign Language Communication (2025)
# 46. Kling-Avatar: Grounding Multimodal Instructions for Cascaded Long-Duration Avatar Animation Synthesis (2025)
# 47. A universal animal communication tempo resonates with the receiver's brain (2025)
# 48. Formal Verification of Physical Layer Security Protocols for Next-Generation Communication Networks (extended version) (2025)
# 49. Controllable Single-shot Animation Blending with Temporal Conditioning (2025)
# 50. Rethinking scale in network neuroscience: Contributions and opportunities at the nanoscale (2025)
# 51. koboshi: A Base That Animates Everyday Objects (2025)
# 52. Privacy Preserving Inference of Personalized Content for Out of Matrix Users (2025)
# 53. LLMs vs. Chinese Anime Enthusiasts: A Comparative Study on Emotionally Supportive Role-Playing (2025)
# 54. UniTalker: Conversational Speech-Visual Synthesis (2025)
# 55. A semi-automatic approach to study population dynamics based on population pyramids (2025)
# 56. Examining the Effects of Human-Likeness of Avatars on Emotion Perception and Emotion Elicitation (2025)
# 57. StreamME: Simplify 3D Gaussian Avatar within Live Stream (2025)
# 58. SceneLoom: Communicating Data with Scene Context (2025)
# 59. STITCH: Simultaneous Thinking and Talking with Chunked Reasoning for Spoken Language Models (2025)
# 60. Feasibility of Energy Neutral Wildlife Tracking using Multi-Source Energy Harvesting (2025)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 3 (Results 61 to 90) ---
# 61. ATL-Diff: Audio-Driven Talking Head Generation with Early Landmarks-Guide Noise Diffusion (2025)
# 62. Speak2Sign3D: A Multi-modal Pipeline for English Speech to American Sign Language Animation (2025)
# 63. Programmable skyrmions for robust communication and intelligent sensing (2025)
# 64. SceneDiffuser++: City-Scale Traffic Simulation via a Generative World Model (2025)
# 65. Malicious earworms and useful memes, how the far-right surfs on TikTok audio trends (2025)
# 66. See What I Mean? Expressiveness and Clarity in Robot Display Design (2025)
# 67. Data Compression with Relative Entropy Coding (2025)
# 68. Public Acceptance of Cybernetic Avatars in the service sector: Evidence from a Large-Scale Survey in Dubai (2025)
# 69. Integrating Large Language Models into Text Animation: An Intelligent Editing System with Inline and Chat Interaction (2025)
# 70. Plant Bioelectric Early Warning Systems: A Five-Year Investigation into Human-Plant Electromagnetic Communication (2025)
# 71. Dynamic Social Networks in Dairy Cows (2025)
# 72. TalkingMachines: Real-Time Audio-Driven FaceTime-Style Video via Autoregressive Diffusion Models (2025)
# 73. Natural, Artificial, and Human Intelligences (2025)
# 74. Silence is Golden: Leveraging Adversarial Examples to Nullify Audio Control in LDM-based Talking-Head Generation (2025)
# 75. ZooplanktonBench: A Geo-Aware Zooplankton Recognition and Classification Dataset from Marine Observations (2025)
# 76. An Eye for a Treat: Human Gazing Modulates Begging by Free-ranging Dogs (2025)
# 77. Understanding Generative AI Capabilities in Everyday Image Editing Tasks (2025)
# 78. Brain volume predicts survival of colliding-spreading messages on mammal brain networks (2025)
# 79. Mouse Lockbox Dataset: Behavior Recognition for Mice Solving Lockboxes (2025)
# 80. AsynFusion: Towards Asynchronous Latent Consistency Models for Decoupled Whole-Body Audio-Driven Avatars (2025)
# 81. Bridging Quantized Artificial Neural Networks and Neuromorphic Hardware (2025)
# 82. Position Paper: Bounded Alignment: What (Not) To Expect From AGI Agents (2025)
# 83. VTutor for High-Impact Tutoring at Scale: Managing Engagement and Real-Time Multi-Screen Monitoring with P2P Connections (2025)
# 84. VTutor: An Animated Pedagogical Agent SDK that Provide Real Time Multi-Model Feedback (2025)
# 85. The insertion of Neomycin cassette impairs maternal and social behaviors in Arc/Arg3.1 knock-out mice (2025)
# 86. Effect of Avatar Head Movement on Communication Behaviour, Experience of Presence and Conversation Success in Triadic Conversations (2025)
# 87. AnimateAnywhere: Rouse the Background in Human Image Animation (2025)
# 88. Low-Rank Adaptation of Neural Fields (2025)
# 89. "Can't believe I'm crying over an anime girl": Public Parasocial Grieving and Coping Towards VTuber Graduation and Termination (2025)
# 90. VLLFL: A Vision-Language Model Based Lightweight Federated Learning Framework for Smart Agriculture (2025)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 4 (Results 91 to 120) ---
# 91. DashChat: Interactive Authoring of Industrial Dashboard Design Prototypes through Conversation with LLM-Powered Agents (2025)
# 92. Advances in Prebiotic Chemistry: the potential of Analog Computing and Navier-Stokes Nernst-Planck (NPNS) Modeling in Organic Electronics Technologies (OECTs) (2025)
# 93. AnimeDL-2M: Million-Scale AI-Generated Anime Image Detection and Localization in Diffusion Era (2025)
# 94. MBE-ARI: A Multimodal Dataset Mapping Bi-directional Engagement in Animal-Robot Interaction (2025)
# 95. InteractAvatar: Modeling Hand-Face Interaction in Photorealistic Avatars with Deformable Gaussians (2025)
# 96. A Multicore and Edge TPU-Accelerated Multimodal TinyML System for Livestock Behavior Recognition (2025)
# 97. Time-adaptive Video Frame Interpolation based on Residual Diffusion (2025)
# 98. Design of Seamless Multi-modal Interaction Framework for Intelligent Virtual Agents in Wearable Mixed Reality Environment (2025)
# 99. A Survey on Human Interaction Motion Generation (2025)
# 100. Formation Control of Multi-agent System with Local Interaction and Artificial Potential Field (2025)
# 101. Virtual Co-presenter: Connecting Deaf and Hard-of-hearing Livestreamers and Hearing audience in E-commerce Livestreaming (2025)
# 102. AnimeGaze: Real-Time Mutual Gaze Synthesis for Anime-Style Avatars in Physical Environments via Behind-Display Camera (2025)
# 103. GeoDEN: A Visual Exploration Tool for Analysing the Geographic Spread of Dengue Serotypes (2025)
# 104. Social hierarchy shapes foraging decisions (2025)
# 105. Who Reaps All the Superchats? A Large-Scale Analysis of Income Inequality in Virtual YouTuber Livestreaming (2025)
# 106. TheoremExplainAgent: Towards Video-based Multimodal Explanations for LLM Theorem Understanding (2025)
# 107. Semi-supervised classification of bird vocalizations (2025)
# 108. AV-Flow: Transforming Text to Audio-Visual Human-like Interactions (2025)
# 109. SkyReels-A1: Expressive Portrait Animation in Video Diffusion Transformers (2025)
# 110. GenComUI: Exploring Generative Visual Aids as Medium to Support Task-Oriented Human-Robot Communication (2025)
# 111. Towards Bio-inspired Heuristically Accelerated Reinforcement Learning for Adaptive Underwater Multi-Agents Behaviour (2025)
# 112. VTutor: An Open-Source SDK for Generative AI-Powered Animated Pedagogical Agents with Multi-Media Output (2025)
# 113. Visual Theory of Mind Enables the Invention of Proto-Writing (2025)
# 114. Virtual Stars, Real Fans: Understanding the VTuber Ecosystem (2025)
# 115. FinchGPT: a Transformer based language model for birdsong analysis (2025)
# 116. Towards spiking analog hardware implementation of a trajectory interpolation mechanism for smooth closed-loop control of a spiking robot arm (2025)
# 117. Hunyuan3D 2.0: Scaling Diffusion Models for High Resolution Textured 3D Assets Generation (2025)
# 118. Human-like Nonverbal Behavior with MetaHumans in Real-World Interaction Studies: An Architecture Using Generative Methods and Motion Capture (2025)
# 119. UnrealZoo: Enriching Photo-realistic Virtual Worlds for Embodied AI (2024)
# 120. A Paragraph is All It Takes: Rich Robot Behaviors from Interacting, Trusted LLMs (2024)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 5 (Results 121 to 150) ---
# 121. Associative memory inspires improvements for in-context learning using a novel attention residual stream architecture (2024)
# 122. VSD2M: A Large-scale Vision-language Sticker Dataset for Multi-frame Animated Sticker Generation (2024)
# 123. Feel my Speech: Automatic Speech Emotion Conversion for Tangible, Haptic, or Proxemic Interaction Design (2024)
# 124. Multispecies Animal Re-ID Using a Large Community-Curated Dataset (2024)
# 125. Bridging Culture and Finance: A Multimodal Analysis of Memecoins in the Web3 Ecosystem (2024)
# 126. INFP: Audio-Driven Interactive Head Generation in Dyadic Conversations (2024)
# 127. FathomVerse: A community science dataset for ocean animal discovery (2024)
# 128. Outstanding framework for simulating and generating anchor trajectory in wireless sensor networks (2024)
# 129. Wireless Electronic-free Mechanical Metamaterial Implants (2024)
# 130. A method for finding distribution of metabolic energy between organismal functions: application to birds' energy expenditures to counteract gravity and to support steady and short flights (2024)
# 131. Generative Visual Communication in the Era of Vision-Language Models (2024)
# 132. Investigation of Vibrational Frequency of Canine Vocal Folds Using a Two-Way Fluid-Solid Interaction Analysis (2024)
# 133. Col-Con: A Virtual Reality Simulation Testbed for Exploring Collaborative Behaviors in Construction (2024)
# 134. User-Centered Design of Socially Assistive Robotic Combined with Non-Immersive Virtual Reality-based Dyadic Activities for Older Adults Residing in Long Term Care Facilities (2024)
# 135. Analysis of Bipartite Networks in Anime Series: Textual Analysis, Topic Clustering, and Modeling (2024)
# 136. AlphaChimp: Tracking and Behavior Recognition of Chimpanzees (2024)
# 137. Allo-AVA: A Large-Scale Multimodal Conversational AI Dataset for Allocentric Avatar Gesture Animation (2024)
# 138. Evaluating the Evaluators: Towards Human-aligned Metrics for Missing Markers Reconstruction (2024)
# 139. Connect-while-in-range: modelling the impact of spatial constraints on dynamic communication network structures (2024)
# 140. UniGlyph: A Seven-Segment Script for Universal Language Representation (2024)
# 141. Streamlined shape of cyborg cockroach promotes traversability in confined environments by gap negotiation (2024)
# 142. Acoustic signaling enables collective perception and control in active matter systems (2024)
# 143. Customizing Generated Signs and Voices of AI Avatars: Deaf-Centric Mixed-Reality Design for Deaf-Hearing Communication (2024)
# 144. TalkinNeRF: Animatable Neural Fields for Full-Body Talking Humans (2024)
# 145. MEDiC: Autonomous Surgical Robotic Assistance to Maximizing Exposure for Dissection and Cautery (2024)
# 146. Generalization in birdsong classification: impact of transfer learning methods and dataset characteristics (2024)
# 147. Unattended field measurement of bird source level (2024)
# 148. Beyond Rationality: Unveiling the Role of Animal Spirits and Inflation Extrapolation in Central Bank Communication of the US (2024)
# 149. Symmetries and synchronization from whole-neural activity in {\it C. elegans} connectome: Integration of functional and structural networks (2024)
# 150. Harnessing Artificial Intelligence for Wildlife Conservation (2024)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 6 (Results 151 to 180) ---
# 151. Ig3D: Integrating 3D Face Representations in Facial Expression Inference (2024)
# 152. Feature Representations for Automatic Meerkat Vocalization Classification (2024)
# 153. Fast Collective Evasion in Self-Localized Swarms of Unmanned Aerial Vehicles (2024)
# 154. AniBalloons: Animated Chat Balloons as Affective Augmentation for Social Messaging and Chatbot Interaction (2024)
# 155. Universal Facial Encoding of Codec Avatars from VR Headsets (2024)
# 156. Towards High-Quality 3D Motion Transfer with Realistic Apparel Animation (2024)
# 157. SMPLOlympics: Sports Environments for Physically Simulated Humanoids (2024)
# 158. Purely vision-based collective movement of robots (2024)
# 159. Highly agile flat swimming robot (2024)
# 160. GuidelineExplorer -- Navigating through the Forrest of Actionable Guidelines on Node-Link Graph Visualization (2024)
# 161. The Vertebrate Breed Ontology: Towards Effective Breed Data Standardization (2024)
# 162. PDP: Physics-Based Character Animation via Diffusion Policy (2024)
# 163. Designing A Sustainable Marine Debris Clean-up Framework without Human Labels (2024)
# 164. Narrative Review of Emotional Expression Support in XR: Psychophysiology of Speech-to-Text Interfaces (2024)
# 165. DogFLW: Dog Facial Landmarks in the Wild Dataset (2024)
# 166. Motion Avatar: Generate Human and Animal Avatars with Arbitrary Motion (2024)
# 167. Enhancing the analysis of murine neonatal ultrasonic vocalizations: Development, evaluation, and application of different mathematical models (2024)
# 168. Semantic Gesticulator: Semantics-Aware Co-Speech Gesture Synthesis (2024)
# 169. Data Format Standardization and DICOM Integration for Hyperpolarized 13C MRI (2024)
# 170. Towards Dog Bark Decoding: Leveraging Human Speech Processing for Automated Bark Classification (2024)
# 171. ID-Animator: Zero-Shot Identity-Preserving Human Video Generation (2024)
# 172. Dynamic Typography: Bringing Text to Life via Video Diffusion Prior (2024)
# 173. Breaking of Time Translation Symmetry and Ergodicity, and Entropy decrease in a Continuous Time Crystal Driven by Nonreciprocal Optical Forces (2024)
# 174. Holon: a cybernetic interface for bio-semiotics (2024)
# 175. Leveraging Large Language Model to Generate a Novel Metaheuristic Algorithm with CRISPE Framework (2024)
# 176. DexDribbler: Learning Dexterous Soccer Manipulation via Dynamic Supervision (2024)
# 177. DanceCamera3D: 3D Camera Movement Synthesis with Music and Dance (2024)
# 178. A Deep Learning Method for Classification of Biophilic Artworks (2024)
# 179. Implicit-Explicit simulation of Mass-Spring-Charge Systems (2024)
# 180. APISR: Anime Production Inspired Real-World Anime Super-Resolution (2024)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 7 (Results 181 to 210) ---
# 181. Learning dynamic representations of the functional connectome in neurobiological networks (2024)
# 182. EmoWear: Exploring Emotional Teasers for Voice Message Interaction on Smartwatches (2024)
# 183. Maia: A Real-time Non-Verbal Chat for Human-AI Interaction (2024)
# 184. HeadStudio: Text to Animatable Head Avatars with 3D Gaussian Splatting (2024)
# 185. A Mechanical Route for Cooperative Transport in Autonomous Robotic Swarms (2024)
# 186. Review of Cetacean's click detection algorithms (2024)
# 187. Dance-to-Music Generation with Encoder-based Textual Inversion (2024)
# 188. Personality Perception in Human Videos Altered by Motion Transfer Networks (2024)
# 189. Eco-evolutionary dynamics of cooperative antimicrobial resistance in a population of fluctuating volume and size (2023)
# 190. The Animal-AI Environment: A Virtual Laboratory For Comparative Cognition and Artificial Intelligence Research (2023)
# 191. SingingHead: A Large-scale 4D Dataset for Singing Head Animation (2023)
# 192. OmniMotionGPT: Animal Motion Generation with Limited Data (2023)
# 193. Effect of the social environment on olfaction and social skills in WT and mouse model of autism (2023)
# 194. SparseCtrl: Adding Sparse Controls to Text-to-Video Diffusion Models (2023)
# 195. Measuring Human-Robot Trust with the MDMT (Multi-Dimensional Measure of Trust) (2023)
# 196. Two-compartment neuronal spiking model expressing brain-state specific apical-amplification, -isolation and -drive regimes (2023)
# 197. Entropy Production on Cooperative Opinion Dynamics (2023)
# 198. A Biologically-Inspired Computational Model of Time Perception (2023)
# 199. Generative Face Video Coding Techniques and Standardization Efforts: A Review (2023)
# 200. ChimpACT: A Longitudinal Dataset for Understanding Chimpanzee Behaviors (2023)
# 201. Deep Learning for Automatic Detection and Facial Recognition in Japanese Macaques: Illuminating Social Networks (2023)
# 202. Misconceptions about quantifying animal encounter and interaction processes (2023)
# 203. Cross-Validation for Training and Testing Co-occurrence Network Inference Algorithms (2023)
# 204. Regularized Contrastive Pre-training for Few-shot Bioacoustic Sound Detection (2023)
# 205. Not your private tête-à-tête: leveraging the power of higher-order networks to study animal communication (2023)
# 206. NimbRo wins ANA Avatar XPRIZE Immersive Telepresence Competition: Human-Centric Evaluation and Lessons Learned (2023)
# 207. Bridging Cognitive Maps: a Hierarchical Active Inference Model of Spatial Alternation Tasks and the Hippocampal-Prefrontal Circuit (2023)
# 208. Repeated Builds During Code Review: An Empirical Study of the OpenStack Community (2023)
# 209. Quantifying the biomimicry gap in biohybrid robot-fish pairs (2023)
# 210. A Fog-based Smart Agriculture System to Detect Animal Intrusion (2023)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 8 (Results 211 to 240) ---
# 211. Finite population effects on optimal communication for social foragers (2023)
# 212. Technical note: ShinyAnimalCV: open-source cloud-based web application for object detection, segmentation, and three-dimensional visualization of animals using computer vision (2023)
# 213. BovineTalk: Machine Learning for Vocalization Analysis of Dairy Cattle under Negative Affective States (2023)
# 214. Affective Affordance of Message Balloon Animations: An Early Exploration of AniBalloons (2023)
# 215. Data sharing and ontology use among agricultural genetics, genomics, and breeding databases and resources of the AgBioData Consortium (2023)
# 216. Artificial Intelligence for Drug Discovery: Are We There Yet? (2023)
# 217. AmadeusGPT: a natural language interface for interactive animal behavioral analysis (2023)
# 218. AnimateDiff: Animate Your Personalized Text-to-Image Diffusion Models without Specific Tuning (2023)
# 219. Evidence of social learning across symbolic cultural barriers in sperm whales (2023)
# 220. Procedurally generating rules to adapt difficulty for narrative puzzle games (2023)
# 221. Depth video data-enabled predictions of longitudinal dairy cow body weight using thresholding and Mask R-CNN algorithms (2023)
# 222. ManimML: Communicating Machine Learning Architectures with Animation (2023)
# 223. HIVA: Holographic Intellectual Voice Assistant (2023)
# 224. Towards Mobility Data Science (Vision Paper) (2023)
# 225. Large language models and (non-)linguistic recursion (2023)
# 226. Universal Language Modelling agent (2023)
# 227. Social Robots As Companions for Lonely Hearts: The Role of Anthropomorphism and Robot Appearance (2023)
# 228. CPNet: Exploiting CLIP-based Attention Condenser and Probability Map Guidance for High-fidelity Talking Face Generation (2023)
# 229. ZS-MSTM: Zero-Shot Style Transfer for Gesture Animation driven by Text and Speech using Adversarial Disentanglement of Multimodal Style Encoding (2023)
# 230. One-Shot Federated Learning for LEO Constellations that Reduces Convergence Time from Days to 90 Minutes (2023)
# 231. A benchmark for computational analysis of animal behavior, using animal-borne tags (2023)
# 232. Agent Heterogeneity Mediates Extremism in an Adaptive Social Network Model (2023)
# 233. Emergent Growth of System Self-Organization & Self-Control (2023)
# 234. Laughing Matters: Introducing Laughing-Face Generation using Diffusion Models (2023)
# 235. DiffuseStyleGesture: Stylized Audio-Driven Co-Speech Gesture Generation with Diffusion Models (2023)
# 236. CatFLW: Cat Facial Landmarks in the Wild Dataset (2023)
# 237. Feebly Interacting Particles: FIPs 2022 workshop report (2023)
# 238. mAedesID: Android Application for Aedes Mosquito Species Identification using Convolutional Neural Network (2023)
# 239. Automated wildlife image classification: An active learning tool for ecological applications (2023)
# 240. Approaching an unknown communication system by latent space exploration and causal inference (2023)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 9 (Results 241 to 270) ---
# 241. Formally Verified Animation for RoboChart using Interaction Trees (2023)
# 242. DeblurSR: Event-Based Motion Deblurring Under the Spiking Representation (2023)
# 243. Human Motion Diffusion as a Generative Prior (2023)
# 244. Molecular Modeling of Aquaporins and Artificial Transmembrane Channels: a mini-review and perspective for plants (2023)
# 245. Interactive Face Video Coding: A Generative Compression Framework (2023)
# 246. Kombucha electronics (2023)
# 247. Communicative Robot Signals: Presenting a New Typology for Human-Robot Interaction (2023)
# 248. A Comprehensive Review of Data-Driven Co-Speech Gesture Generation (2023)
# 249. GeoCode: Interpretable Shape Programs (2022)
# 250. Emergent Computations in Trained Artificial Neural Networks and Real Brains (2022)
# 251. FPGA Implementation of An Event-driven Saliency-based Selective Attention Model (2022)
# 252. TPA-Net: Generate A Dataset for Text to Physics-based Animation (2022)
# 253. Ham2Pose: Animating Sign Language Notation into Pose Sequences (2022)
# 254. Exact solutions to Euler's equations for rigid body motion with application to detumbling satellites (2022)
# 255. A Theory of Unsupervised Translation Motivated by Understanding Animal Communication (2022)
# 256. Complementary Textures. A Novel Approach to Object Alignment in Mixed Reality (2022)
# 257. LLEDA -- Lifelong Self-Supervised Domain Adaptation (2022)
# 258. AEROS: Oceanographic Hyperspectral Imaging and Argos-Tracking CubeSat (2022)
# 259. HREyes: Design, Development, and Evaluation of a Novel Method for AUVs to Communicate Information and Gaze Direction (2022)
# 260. Haven't I Seen You Before? Assessing Identity Leakage in Synthetic Irises (2022)
# 261. The Natural Robotics Contest: Crowdsourced Biomimetic Design (2022)
# 262. Large-scale Text-to-Image Generation Models for Visual Artists' Creative Works (2022)
# 263. Hypergraphs for multiscale cycles in structured data (2022)
# 264. Considerations and Recommendations from the ISMRM Diffusion Study Group for preclinical diffusion MRI: Part 1 -- In vivo small-animal imaging (2022)
# 265. AvatarGo: Plug and Play self-avatars for VR (2022)
# 266. SOCRATES: A Stereo Camera Trap for Monitoring of Biodiversity (2022)
# 267. SATViz: Real-Time Visualization of Clausal Proofs (2022)
# 268. Neural3Points: Learning to Generate Physically Realistic Full-body Motion for Virtual Reality Users (2022)
# 269. A virtual reality-based method for examining audiovisual prosody perception (2022)
# 270. Zero-Shot Style Transfer for Gesture Animation driven by Text and Speech using Adversarial Disentanglement of Multimodal Style Encoding (2022)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 10 (Results 271 to 300) ---
# 271. Auggie: Encouraging Effortful Communication through Handcrafted Digital Experiences (2022)
# 272. VRKitchen2.0-IndoorKit: A Tutorial for Augmented Indoor Scene Building in Omniverse (2022)
# 273. The Prince and the Pauper: Evidence for the early high-redshift formation of the Galactic $α$-poor disc population (2022)
# 274. Can Mobile Technology Improve Female Entrepreneurship? Evidence from Nepal (2022)
# 275. Garment Avatars: Realistic Cloth Driving using Pattern Registration (2022)
# 276. Robotic Planning under Uncertainty in Spatiotemporal Environments in Expeditionary Science (2022)
# 277. Collective Intelligence as Infrastructure for Reducing Broad Global Catastrophic Risks (2022)
# 278. Revisiting Javanese pranata mangsa: On ethnic groups and the four sample cities in Java (2022)
# 279. EMOCA: Emotion Driven Monocular Face Capture and Animation (2022)
# 280. Information-theoretic Limits for Testing Community Structures in Weighted Networks (2022)
# 281. Animal Kingdom: A Large and Diverse Dataset for Animal Behavior Understanding (2022)
# 282. Compressive Sensing-Based Recovery of Molecular Mixtures with Cross-Reactive Receptor Arrays (2022)
# 283. Generative Adversarial Networks for Image Augmentation in Agriculture: A Systematic Review (2022)
# 284. Turnover in close friendships: age and gender differences (2022)
# 285. Distributed Vehicular Dynamic Spectrum Access for Platooning Environments (2022)
# 286. Early Adapting to Trends: Self-Stabilizing Information Spread using Passive Communication (2022)
# 287. SETI, evolution and human history merged into a mathematical model (2022)
# 288. Olfaction-inspired MCs: Molecule Mixture Shift Keying and Cross-Reactive Receptor Arrays (2022)
# 289. Communication Layer Security in Smart Farming: A Survey on Wireless Technologies (2022)
# 290. Scales and Locomotion: Non-Reversible Longitudinal Drag (2022)
# 291. Speciesist bias in AI -- How AI applications perpetuate discrimination and unfair outcomes against animals (2022)
# 292. Hidden bawls, whispers, and yelps: can text be made to sound more than just its words? (2022)
# 293. Modern Augmented Reality: Applications, Trends, and Future Directions (2022)
# 294. Towards Battery-Free Machine Learning and Inference in Underwater Environments (2022)
# 295. Stochastic dynamics of social patch foraging decisions (2022)
# 296. On the Complementarity of Images and Text for the Expression of Emotions in Social Media (2022)
# 297. Choosing an Appropriate Platform and Workflow for Processing Camera Trap Data using Artificial Intelligence (2022)
# 298. pymdp: A Python library for active inference in discrete state spaces (2022)
# 299. Pavlovian Signalling with General Value Functions in Agent-Agent Temporal Decision Making (2022)
# 300. A Review of Deep Learning Techniques for Markerless Human Motion on Synthetic Datasets (2022)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 11 (Results 301 to 330) ---
# 301. Local accumulation time for diffusion in cells with gap junction coupling (2022)
# 302. Ant colonization processed algorithm for design of a toroidal shaped mobile 5G antenna (2022)
# 303. A general technique for the estimation of farm animal body part weights from CT scans and its applications in a rabbit breeding program (2021)
# 304. VibEmoji: Exploring User-authoring Multi-modal Emoticons in Social Communication (2021)
# 305. Analysis of animal-related electric outages using species distribution models and community science data (2021)
# 306. Computational bioacoustics with deep learning: a review and roadmap (2021)
# 307. GenMotion: Data-driven Motion Generators for Real-time Animation Synthesis (2021)
# 308. PyTorch Connectomics: A Scalable and Flexible Segmentation Framework for EM Connectomics (2021)
# 309. Spiking Control Systems (2021)
# 310. Attention based Occlusion Removal for Hybrid Telepresence Systems (2021)
# 311. V2C: Visual Voice Cloning (2021)
# 312. Neural Fields in Visual Computing and Beyond (2021)
# 313. Invariant Risk Minimisation for Cross-Organism Inference: Substituting Mouse Data for Human Data in Human Risk Factor Discovery (2021)
# 314. Life-History traits and the replicator equation (2021)
# 315. MaTIC: a Mathematical Theory of Inferential Communication (2021)
# 316. Collective decision-making under changing social environments among agents adapted to sparse connectivity (2021)
# 317. Seeing biodiversity: perspectives in machine learning for wildlife conservation (2021)
# 318. Machine Learning applied to asteroid dynamics (2021)
# 319. Bayesian Multi-Species N-Mixture Models for Unmarked Animal Communities (2021)
# 320. FathomNet: A global image database for enabling artificial intelligence in the ocean (2021)
# 321. NimbRo Avatar: Interactive Immersive Telepresence with Force-Feedback Telemanipulation (2021)
# 322. An animated picture says at least a thousand words: Selecting Gif-based Replies in Multimodal Dialog (2021)
# 323. From Bench to Bedside: The First Live Robotic Surgery on the dVRK to Enable Remote Telesurgery with Motion Scaling (2021)
# 324. Facilitating human-wildlife cohabitation through conflict prediction (2021)
# 325. A Novel Dataset for Keypoint Detection of quadruped Animals from Images (2021)
# 326. Goal-driven text descriptions for images (2021)
# 327. A functional skeleton transfer (2021)
# 328. Trade-off between deep learning for species identification and inference about predator-prey co-occurrence: Reproducible R workflow integrating models in computer vision and ecological statistics (2021)
# 329. Visualizing Uncertainty in Probabilistic Graphs with Network Hypothetical Outcome Plots (NetHOPs) (2021)
# 330. Beyond Tracking: Using Deep Learning to Discover Novel Interactions in Biological Swarms (2021)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 12 (Results 331 to 360) ---
# 331. On the Virality of Animated GIFs on Tumblr (2021)
# 332. Visualizing Income Distribution in the United States (2021)
# 333. Learning Proxemic Behavior Using Reinforcement Learning with Cognitive Agents (2021)
# 334. Making cosmic particle accelerators visible and audible (2021)
# 335. TLA: Twitter Linguistic Analysis (2021)
# 336. Passing a Non-verbal Turing Test: Evaluating Gesture Animations Generated from Speech (2021)
# 337. Some Problems of Deployment and Navigation of Civilian Aerial Drones (2021)
# 338. Evaluation of deep lift pose models for 3D rodent pose estimation based on geometrically triangulated data (2021)
# 339. Spatial structure and information transfer in visual networks (2021)
# 340. One-way dependent clusters and stability of cluster synchronization in directed networks (2021)
# 341. Prevention Of Attack In Vehicular Adhoc Network Using Trust Model (2021)
# 342. Overcoming the Distance Estimation Bottleneck in Estimating Animal Abundance with Camera Traps (2021)
# 343. On the Internet, Nobody Knows You're a Dog... Unless You're Another Dog (2021)
# 344. Few-shot Partial Multi-view Learning (2021)
# 345. Cetacean Translation Initiative: a roadmap to deciphering the communication of sperm whales (2021)
# 346. Designing Building Blocks for Open-Ended Early Literacy Software (2021)
# 347. Why is neural connection weight a weak predictor of correlated neural activity? (2021)
# 348. Hopscotching Jellyfish: combining different duty cycle kinematics can lead to enhanced swimming performance (2021)
# 349. Modelling Animal Biodiversity Using Acoustic Monitoring and Deep Learning (2021)
# 350. Inference-Based Deterministic Messaging For Multi-Agent Communication (2021)
# 351. XNAT-PIC: Extending XNAT to Preclinical Imaging Centers (2021)
# 352. Significant Otter: Understanding the Role of Biosignals in Communication (2021)
# 353. The scaling of social interactions across animal species (2021)
# 354. The Arc of the Data Scientific Universe (2021)
# 355. Aquanims: Area-Preserving Animated Transitions in Statistical Data Graphics based on a Hydraulic Metaphor (2021)
# 356. Communication Aid for Non-English Speaking Newcomers (2021)
# 357. Artificial Intelligence & Cooperation (2020)
# 358. EasyPBR: A Lightweight Physically-Based Renderer (2020)
# 359. Low-Bandwidth Communication Emerges Naturally in Multi-Agent Learning Systems (2020)
# 360. Learning a Deep Generative Model like a Program: the Free Category Prior (2020)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 13 (Results 361 to 390) ---
# 361. Multi-Agent Active Search using Realistic Depth-Aware Noise Model (2020)
# 362. Reducing latency and bandwidth for video streaming using keypoint extraction and digital puppetry (2020)
# 363. Resource-Constrained Federated Learning with Heterogeneous Labels and Models (2020)
# 364. The Aggregator Model of Spatial Cognition (2020)
# 365. The Search for Feebly-Interacting Particles (2020)
# 366. A Global View of Standards for Open Image Data Formats and Repositories (2020)
# 367. Arbitrary Video Style Transfer via Multi-Channel Correlation (2020)
# 368. Smoothed Particle Hydrodynamics Techniques for the Physics Based Simulation of Fluids and Solids (2020)
# 369. Analysing Twitter Semantic Networks: the case of 2018 Italian Elections (2020)
# 370. A Metamodel and Framework for AGI (2020)
# 371. ANGUS: Real-time manipulation of vocal roughness for emotional speech transformations (2020)
# 372. Real-Time Cleaning and Refinement of Facial Animation Signals (2020)
# 373. Bayesian Context Trees: Modelling and exact inference for discrete time series (2020)
# 374. Style Transfer for Co-Speech Gesture Animation: A Multi-Speaker Conditional-Mixture Approach (2020)
# 375. Time Perception: A Review on Psychological, Computational and Robotic Models (2020)
# 376. Who Left the Dogs Out? 3D Animal Reconstruction with Expectation Maximization in the Loop (2020)
# 377. Structural and Dynamical Mechanisms of a Naturally Occurring Variant of the Human Prion Protein in Preventing Prion Conversion (2020)
# 378. A Robust Interactive Facial Animation Editing System (2020)
# 379. Animated GIF optimization by adaptive color local table management (2020)
# 380. Seamlessly Integrating Loops That Matter into Model Development and Analysis (2020)
# 381. TAO: A Large-Scale Benchmark for Tracking Any Object (2020)
# 382. Electro-Quasistatic Animal Body Communication for Chronic Untethered Rodent Biopotential Recording (2020)
# 383. Community Detection Clustering via Gumbel Softmax (2020)
# 384. Towards A Sign Language Gloss Representation Of Modern Standard Arabic (2020)
# 385. System of Computer Modeling and Features of their use in the Educational Process of General Secondary Eeducation (2020)
# 386. Power of Artificial Intelligence to Diagnose and Prevent Further COVID-19 Outbreak: A Short Communication (2020)
# 387. Roommate Compatibility Detection Through Machine Learning Techniques (2020)
# 388. A Digital Ecosystem for Animal Movement Science: Making animal movement datasets, data-linkage techniques, methods, and environmental layers easier to find, interpret, and analyze (2020)
# 389. An Interactive Gravitational-Wave Detector Model for Museums and Fairs (2020)
# 390. History of Onychophorology, 1826-2020 (2020)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 14 (Results 391 to 420) ---
# 391. Fluid Dynamics-Based Distance Estimation Algorithm for Macroscale Molecular Communication (2020)
# 392. Differences of Human Perceptions of a Robot Moving using Linear or Slow in, Slow out Velocity Profiles When Performing a Cleaning Task (2020)
# 393. Novel Molecular Signaling Method and System for Molecular Communication in Human Body (2020)
# 394. Advertisers Jump on Coronavirus Bandwagon: Politics, News, and Business (2020)
# 395. A modeling study of predator--prey interaction propounding honest signals and cues (2020)
# 396. A Disk Scheduling Algorithm Based on ANT Colony Optimization (2020)
# 397. Mesoscale structure of wrinkle patterns and defect-proliferated liquid crystalline phases (2020)
# 398. Extracting Semantic Indoor Maps from Occupancy Grids (2020)
# 399. Understanding the spatial burden of gender-based violence: Modelling patterns of violence in Nairobi, Kenya through geospatial information (2020)
# 400. The Information in Emotion Communication (2020)
# 401. Visual Exploration of Movement Relatedness for Multi-species Ecology Analysis (2020)
# 402. ABCTracker: an easy-to-use, cloud-based application for tracking multiple objects (2020)
# 403. Brain-to-brain Wireless Communication and Technologies Beyond 5G (2019)
# 404. Brain-to-Brain Communication Based on Wireless Technologies: Actual and Future Perspectives (2019)
# 405. Proceedings Tenth International Workshop on Graph Computation Models (2019)
# 406. That and There: Judging the Intent of Pointing Actions with Robotic Arms (2019)
# 407. Subreddit R/unpopularopinion: Against the Spiral of Silence (2019)
# 408. Describing Alt-Right communities and their discourse on Twitter during the 2018 US mid-term elections (2019)
# 409. Expressive Inverse Kinematics Solving in Real-time for Virtual and Robotic Interactive Characters (2019)
# 410. Swarm Hunting and Clusters Turning Inside Out in Chemically Communicating Active Mixtures (2019)
# 411. Military Dog Based Optimizer and its Application to Fake Review (2019)
# 412. Thinking Inside the Box: An Advection-Diffusion Model of Animal Movement in an Enclosed Region (2019)
# 413. Enhanced distributed data aggregation method in the internet of things (2019)
# 414. TERA: the Toxicological Effect and Risk Assessment Knowledge Graph (2019)
# 415. An artifcial life approach to studying niche differentiation in soundscape ecology (2019)
# 416. Interaction Mechanisms Quantified from Dynamical Features of Frog Choruses (2019)
# 417. Towards Robust Direction Invariance in Character Animation (2019)
# 418. Efficient Pipeline for Camera Trap Image Review (2019)
# 419. The iWildCam 2019 Challenge Dataset (2019)
# 420. Perspective Taking in Deep Reinforcement Learning Agents (2019)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 15 (Results 421 to 450) ---
# 421. DeepTEGINN: Deep Learning Based Tools to Extract Graphs from Images of Neural Networks (2019)
# 422. Seeing Things from a Different Angle: Discovering Diverse Perspectives about Claims (2019)
# 423. Sea of Genes: Combining Animation and Narrative Strategies to Visualize Metagenomic Data for Museums (2019)
# 424. When is now in a distributed system? Animated motion (could) set the present in brain networks (2019)
# 425. "Tom" pet robot applied to urban autism (2019)
# 426. Semantic categories of artifacts and animals reflect efficient coding (2019)
# 427. NeuroPod: a real-time neuromorphic spiking CPG applied to robotics (2019)
# 428. REVERIE: Remote Embodied Visual Referring Expression in Real Indoor Environments (2019)
# 429. Don't be jelly: Exploring effective jellyfish locomotion (2019)
# 430. A Theory of Discrete Hierarchies as Optimal Cost-Adjusted Productivity Organisations (2019)
# 431. AMASS: Archive of Motion Capture as Surface Shapes (2019)
# 432. Out of Site: Empowering a New Approach to Online Boycotts (2019)
# 433. "The Perfect One": Understanding Communication Practices and Challenges with Animated GIFs (2019)
# 434. Spatial memory and taxis-driven pattern formation in model ecosystems (2019)
# 435. Hybrid Heterogeneous Routing Scheme for Improved Network Performance in WSNs for Animal Tracking (2019)
# 436. Automatic Detection and Compression for Passive Acoustic Monitoring of the African Forest Elephant (2019)
# 437. Categorization in the Wild: Generalizing Cognitive Models to Naturalistic Data across Languages (2019)
# 438. Similarity Learning Networks for Animal Individual Re-Identification -- Beyond the Capabilities of a Human Observer (2019)
# 439. Quantitative analysis of timing in animal vocal sequences (2019)
# 440. Auditory information loss in real-world listening environments (2019)
# 441. Using Key Player Analysis as a Method for Examining the Role of Community Animators in Technology Adoption (2019)
# 442. Live Emoji: Semantic Emotional Expressiveness of 2D Live Animation (2019)
# 443. Community Animation: Exploring a design space that leverages geosocial networking to increase community engagement (2019)
# 444. Doppler-Resilient 802.11ad-Based Ultra-Short Range Automotive Joint Radar-Communications System (2019)
# 445. Navigating through the R packages for movement (2019)
# 446. Formal models of Structure Building in Music, Language and Animal Songs (2019)
# 447. The Design and Deployment of an End-to-end IoT Infrastructure for the Natural Environment (2019)
# 448. Stroke-based sketched symbol reconstruction and segmentation (2019)
# 449. On the Euler-Alignment system with weakly singular communication weights (2019)
# 450. Spatiotemporal Calibration of Atmospheric Nitrogen Dioxide Concentration Estimates From an Air Quality Model for Connecticut (2019)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 16 (Results 451 to 480) ---
# 451. A Full Probabilistic Model for Yes/No Type Crowdsourcing in Multi-Class Classification (2019)
# 452. Deep learning for pedestrians: backpropagation in CNNs (2018)
# 453. Past, Present, and Future Approaches Using Computer Vision for Animal Re-Identification from Camera Trap Data (2018)
# 454. Reconstructing the visual perception of honey bees in complex 3-D worlds (2018)
# 455. Influence of visual cues on head and eye movements during listening tasks in multi-talker audiovisual environments with animated characters (2018)
# 456. The need for an integrative thinking to fight against emerging infectious diseases (2018)
# 457. Optimising observing strategies for monitoring animals using drone-mounted thermal infrared cameras (2018)
# 458. Objective estimation of sensory thresholds based on neurophysiological parameters (2018)
# 459. Automatic acoustic identification of individual animals: Improving generalisation across species and recording conditions (2018)
# 460. A Decentralized Mobile Computing Network for Multi-Robot Systems Operations (2018)
# 461. Disrupting the Coming Robot Stampedes: Designing Resilient Information Ecologies (2018)
# 462. Chalktalk : A Visualization and Communication Language -- As a Tool in the Domain of Computer Science Education (2018)
# 463. Industrial Smoke Detection and Visualization (2018)
# 464. Investigating Crowd Creativity in Online Music Communities (2018)
# 465. Modelling diverse sources of Clostridium difficile in the community: importance of animals, infants and asymptomatic carriers (2018)
# 466. Ensemble Learning Applied to Classify GPS Trajectories of Birds into Male or Female (2018)
# 467. New formulation of the Logistic-Gaussian process to analyze trajectory tracking data (2018)
# 468. AniCode: Authoring Coded Artifacts for Network-Free Personalized Animations (2018)
# 469. Running on empty: Recharge dynamics from animal movement data (2018)
# 470. Continuous-Scale Kinetic Fluid Simulation (2018)
# 471. Connectors meet Choreographies (2018)
# 472. Simon's Anthill: Mapping and Navigating Belief Spaces (2018)
# 473. Community-Empowered Air Quality Monitoring System (2018)
# 474. This One Simple Trick Disrupts Digital Communities (2018)
# 475. Personal Volunteer Computing (2018)
# 476. Competition-induced increase of species abundance in mutualistic networks (2018)
# 477. BioTracker: An Open-Source Computer Vision Framework for Visual Animal Tracking (2018)
# 478. Investigating Collaboration Within Online Communities: Software Development Vs. Artistic Creation (2018)
# 479. Dancing Honey bee Robot Elicits Dance-Following and Recruits Foragers (2018)
# 480. Learning to Gather without Communication (2018)
#
# Waiting 5 seconds before fetching the next batch...
#
# --- BATCH 17 (Results 481 to 510) ---
# 481. Mobility as an Alternative Communication Channel: A Survey (2018)
# 482. Deep Neural Network-based Cooperative Visual Tracking through Multiple Micro Aerial Vehicles (2018)
# 483. The physicist's guide to one of biotechnology's hottest new topics: CRISPR-Cas (2017)
# 484. Choreographic and Somatic Approaches for the Development of Expressive Robotic Systems (2017)
# 485. On the organization of grid and place cells: Neural de-noising via subspace learning (2017)
# 486. The evolution and structure of biomedical knowledge on cytochrome P450 (2017)
# 487. Virtual Astronaut for Scientific Visualization - A Prototype for Santa Maria Crater on Mars (2017)
# 488. Limitations in Predicting the Space Radiation Health Risk for Exploration Astronauts (2017)
# 489. Collaboration Success Factors in an Online Music Community (2017)
# 490. Small Animal Multivariate Brain Analysis (SAMBA): A High Throughput Pipeline with a Validation Framework (2017)
# 491. Sketch-pix2seq: a Model to Generate Sketches of Multiple Categories (2017)
# 492. Plant survival and keystone pollinator species in stochastic coextinction models: role of intrinsic dependence on animal-pollination (2017)
# 493. A Mimetic Strategy to Engage Voluntary Physical Activity In Interactive Entertainment (2017)
# 494. Cell contraction induces long-ranged stress stiffening in the extracellular matrix (2017)
# 495. Using Posters to Recommend Anime and Mangas in a Cold-Start Scenario (2017)
# 496. Automatic detection and decoding of honey bee waggle dances (2017)
# 497. Microbial mutualism at a distance: the role of geometry in diffusive exchanges (2017)
# 498. Speech-driven Animation with Meaningful Behaviors (2017)
# 499. Anisotropic EM Segmentation by 3D Affinity Learning and Agglomeration (2017)
# ...
#
# * **[Queuing models for abstracting interactions in Bacterial communities](http://arxiv.org/abs/1508.00942v2)** (2015) <br> 👤 *Nicolò Michelusi, James Boedicker, Mohamed Y. El-Naggar, Urbashi Mitra*
#
# * **[On the Digital Daily Cycles of Individuals](http://arxiv.org/abs/1507.08199v1)** (2015) <br> 👤 *Talayeh Aledavood, Sune Lehmann, Jari Saramäki*
#
# * **[A Batteryless Sensor ASIC for Implantable Bio-impedance Applications](http://arxiv.org/abs/1507.03388v1)** (2015) <br> 👤 *Saul Rodriguez, Stig Ollmar, Muhammad Waqar, Ana Rusu*
#
# * **[The Cost of Collaboration for Code and Art: Evidence from a Remixing Community](http://arxiv.org/abs/1507.01297v1)** (2015) <br> 👤 *Benjamin Mako Hill, Andrés Monroy-Hernández*
#
# * **[The Remixing Dilemma: The Trade-off Between Generativity and Originality](http://arxiv.org/abs/1507.01295v1)** (2015) <br> 👤 *Benjamin Mako Hill, Andrés Monroy-Hernández*
#
# * **[Computers Can't Give Credit: How Automatic Attribution Falls Short in an Online Remixing Community](http://arxiv.org/abs/1507.01285v1)** (2015) <br> 👤 *Andrés Monroy-Hernández, Benjamin Mako Hill, Jazmin Gonzalez-Rivero, danah boyd*
#
# * **[Responses to remixing on a social media sharing website](http://arxiv.org/abs/1507.01284v1)** (2015) <br> 👤 *Benjamin Mako Hill, Andrés Monroy-Hernández, Kristina R. Olson*
#
# * **[Rendering-as-a-Service: Taxonomy and Comparison](http://arxiv.org/abs/1505.06543v1)** (2015) <br> 👤 *Ruby Annette, Aisha Banu, Subash Chandran*
#
# * **[Productivity of pre-modern agriculture in the Cucuteni-Trypillia area](http://arxiv.org/abs/1505.05121v1)** (2015) <br> 👤 *A. Shukurov, M. Yu. Videiko, G. R. Sarson, K. Davison, R. Shiel, P. M. Dolukhanov, G. A. Pashkevich*
#
# * **[Use of Effective Audio in E-learning Courseware](http://arxiv.org/abs/1503.04837v1)** (2015) <br> 👤 *Kisor Ray*
#
# * **[Collective achievement of making in cosplay culture](http://arxiv.org/abs/1503.01066v1)** (2015) <br> 👤 *Rie Matsuura, Daisuke Okabe*
#
# * **[Fast event-based epidemiological simulations on national scales](http://arxiv.org/abs/1502.02908v3)** (2015) <br> 👤 *Pavol Bauer, Stefan Engblom, Stefan Widgren*
#
# * **[The Spatial Structure of Transnational Human Activity](http://arxiv.org/abs/1501.05921v1)** (2015) <br> 👤 *Emanuel Deutschmann*
#
# * **[Caracterização de circuitos pecuários com base em redes de movimentação de animais](http://arxiv.org/abs/1501.02278v1)** (2015) <br> 👤 *José Henrique Hildebrand Grisi-Filho, Marcos Amaku*
#
# * **[Social Interactions vs Revisions, What is important for Promotion in Wikipedia?](http://arxiv.org/abs/1501.01526v1)** (2015) <br> 👤 *Romain Picot-Clémente, Cécile Bothorel, Nicolas Jullien*
#
# * **[A prototype Malayalam to Sign Language Automatic Translator](http://arxiv.org/abs/1412.7415v2)** (2014) <br> 👤 *Jestin Joy, Kannan Balakrishnan*
#
# * **[Versinus: a visualization method for graphs in evolution](http://arxiv.org/abs/1412.7311v1)** (2014) <br> 👤 *Renato Fabbri*
#
# * **[A Novel Degree of Freedom in Flapping Wings Shows Promise for a Dual Aerial/Aquatic Vehicle Propulsor](http://arxiv.org/abs/1412.3843v2)** (2014) <br> 👤 *Jacob S. Izraelevitz, Michael S. Triantafyllou*
#
# * **[Mixed mode synchronization and network bursting of neurons with post-inhibitory rebound](http://arxiv.org/abs/1412.2058v1)** (2014) <br> 👤 *Roman Nagornov, Grigory Osipov, Maxim Komarov, Arkady Pikovsky, Andrey Shilnikov*
#
# * **[Individual discrimination of freely swimming pulse-type electric fish from electrode array recordings](http://arxiv.org/abs/1412.1759v1)** (2014) <br> 👤 *Paulo Matias, Jan Frans Willem Slaets, Reynaldo Daniel Pinto*
#
# * **[Multiple object tracking with context awareness](http://arxiv.org/abs/1411.7935v2)** (2014) <br> 👤 *Laura Leal-Taixé*
#
# * **[Child Education Through Animation: An Experimental Study](http://arxiv.org/abs/1411.1897v1)** (2014) <br> 👤 *Md Baharul Islam, Arif Ahmed, Md Kabirul Islam, Abu Kalam Shamsuddin*
#
# * **[Ctrax extensions for tracking in difficult lighting conditions](http://arxiv.org/abs/1409.7272v1)** (2014) <br> 👤 *Ulrich Stern, Chung-Hui Yang*
#
# * **[Collapse of an ecological network in Ancient Egypt](http://arxiv.org/abs/1409.7006v1)** (2014) <br> 👤 *Justin D. Yeakel, Mathias M. Pires, Lars Rudolf, Nathaniel J. Dominy, Paul L. Koch, Paulo R. Guimarães, Thilo Gross*
#
# * **[Location Prediction: Communities Speak Louder than Friends](http://arxiv.org/abs/1408.1228v3)** (2014) <br> 👤 *Jun Pang, Yang Zhang*
#
# * **[A macro-level model for investigating the effect of directional bias on network coverage](http://arxiv.org/abs/1407.5762v2)** (2014) <br> 👤 *Graeme Smith, J. W. Sanders, Qin Li*
#
# * **[Step selection techniques uncover the environmental predictors of space use patterns in flocks of Amazonian birds](http://arxiv.org/abs/1403.6869v3)** (2014) <br> 👤 *Jonathan R. Potts, Karl Mokross, Philip C Stouffer, Mark A. Lewis*
#
# * **[The state of play of ASC-Inclusion: An Integrated Internet-Based Environment for Social Inclusion of Children with Autism Spectrum Conditions](http://arxiv.org/abs/1403.5912v1)** (2014) <br> 👤 *Björn Schuller, Erik Marchi, Simon Baron-Cohen, Helen O'Reilly, Delia Pigat, Peter Robinson, Ian Daves*
#
# * **[Saliency Based Control in Random Feature Networks](http://arxiv.org/abs/1403.5462v2)** (2014) <br> 👤 *John Baillieul, Zhaodan Kong*
#
# * **[Modeling the emergence of modular leadership hierarchy during the collective motion of herds made of harems](http://arxiv.org/abs/1403.0260v4)** (2014) <br> 👤 *Katalin Ozogány, Tamás Vicsek*
#
# * **[Outdoor flocking and formation flight with autonomous aerial robots](http://arxiv.org/abs/1402.3588v2)** (2014) <br> 👤 *Gábor Vásárhelyi, Csaba Virágh, Gergő Somorjai, Norbert Tarcai, Tamás Szörényi, Tamás Nepusz, Tamás Vicsek*
#
# * **[Optimal search in interacting populations:Gaussian jumps vs Levy flights](http://arxiv.org/abs/1401.7124v1)** (2014) <br> 👤 *Ricardo Martinez-Garcia, Justin M. Calabrese, Cristobal Lopez*
#
# * **[Consciousness results when communication modifies the form of self-estimated fitness](http://arxiv.org/abs/1401.6761v2)** (2014) <br> 👤 *J. H. van Hateren*
#
# * **[A Study of Actor and Action Semantic Retention in Video Supervoxel Segmentation](http://arxiv.org/abs/1311.3318v1)** (2013) <br> 👤 *Chenliang Xu, Richard F. Doell, Stephen José Hanson, Catherine Hanson, Jason J. Corso*
#
# * **[Fuzzy Mating Behavior Enhances Species Coexistence and Delays Extinction in Diverse Communities](http://arxiv.org/abs/1311.2924v1)** (2013) <br> 👤 *Charles Cannon, Manuel Lerdau*
#
# * **[Emergence of macroscopic directed motion in populations of motile colloids](http://arxiv.org/abs/1311.2017v1)** (2013) <br> 👤 *Antoine Bricard, Jean-Baptiste Caussin, Nicolas Desreumaux, Olivier Dauchot, Denis Bartolo*
#
# * **[Optimal Cooperative Searching Using Purely Repulsive Interactions](http://arxiv.org/abs/1311.1549v1)** (2013) <br> 👤 *Noriyuki P. Tani, Alan Blatt, David A. Quint, Ajay Gopinathan*
#
# * **[Self-controlled growth, coherent shrinkage, eternal life in a self-bounded space and other amazing evolutionary dynamics of stochastic pattern formation and growth models inspired by Conways Game of Life](http://arxiv.org/abs/1310.7604v1)** (2013) <br> 👤 *Leonid Yaroslavsky*
#
# * **[Flocking algorithm for autonomous flying robots](http://arxiv.org/abs/1310.3601v3)** (2013) <br> 👤 *Csaba Virágh, Gábor Vásárhelyi, Norbert Tarcai, Tamás Szörényi, Gergő Somorjai, Tamás Nepusz, Tamás Vicsek*
#
# * **[Emergence of structural and dynamical properties of ecological mutualistic networks](http://arxiv.org/abs/1308.4807v1)** (2013) <br> 👤 *Samir Suweis, Filippo Simini, Jayanth R. Banavar, Amos Maritan*
#
# * **[Complexity in animal communication: Estimating the size of N-Gram structures](http://arxiv.org/abs/1308.3616v2)** (2013) <br> 👤 *Reginald D. Smith*
#
# * **[Clustering of Complex Networks and Community Detection Using Group Search Optimization](http://arxiv.org/abs/1307.1372v2)** (2013) <br> 👤 *G. Kishore Kumar, V. K. Jayaraman*
#
# * **[Visualizing Astronomical Data with Blender](http://arxiv.org/abs/1306.3481v1)** (2013) <br> 👤 *Brian R. Kent*
#
# * **[Effect of Mobility and Traffic Models on the Energy Consumption in MANET Routing Protocols](http://arxiv.org/abs/1304.3259v1)** (2013) <br> 👤 *Said El Kafhali, Abdelkrim Haqiq*
#
# * **[The Biological Origin of Linguistic Diversity](http://arxiv.org/abs/1302.2937v1)** (2013) <br> 👤 *Andrea Baronchelli, Nick Chater, Romualdo Pastor-Satorras, Morten H. Christiansen*
#
# * **[Interactive Overlays of Journals and the Measurement of Interdisciplinarity on the basis of Aggregated Journal-Journal Citations](http://arxiv.org/abs/1301.1013v2)** (2013) <br> 👤 *Loet Leydesdorff, Ismael Rafols, Chaomei Chen*
#
# * **[Human-Recognizable Robotic Gestures](http://arxiv.org/abs/1212.6273v1)** (2012) <br> 👤 *John-John Cabibihan, Wing-Chee So, Soumo Pramanik*
#
# * **[Quantum Structure in Competing Lizard Communities](http://arxiv.org/abs/1212.0109v2)** (2012) <br> 👤 *Diederik Aerts, Jan Broekaert, Marek Czachor, Maciej Kuna, Barry Sinervo, Sandro Sozzo*
#
# * **[A Survey of Delay Tolerant Networks Routing Protocols](http://arxiv.org/abs/1210.0965v1)** (2012) <br> 👤 *Zhenxin Feng, Kwan-Wu Chin*
#
# * **[Markov Processes with Restart](http://arxiv.org/abs/1206.5674v1)** (2012) <br> 👤 *Konstantin Avrachenkov, Alexei Piunovskiy, Zhang Yi*
#
# * **[Collaborative search on the plane without communication](http://arxiv.org/abs/1205.2170v2)** (2012) <br> 👤 *Ofer Feinerman, Amos Korman, Zvi Lotker, Jean-Sébastien Sereni*
#
# * **[Standing on the Shoulders of Their Peers: Success Factors for Massive Cooperation Among Children Creating Open Source Animations and Games on Their Smartphones](http://arxiv.org/abs/1204.6408v1)** (2012) <br> 👤 *Tobias Gritschacher, Wolfgang Slany*
#
# * **[Machine Cognition Models: EPAM and GPS](http://arxiv.org/abs/1204.1653v1)** (2012) <br> 👤 *Ali Elouafiq*
#
# * **[The Habitable Zone Gallery](http://arxiv.org/abs/1202.2377v1)** (2012) <br> 👤 *Stephen R. Kane, Dawn M. Gelino*
#
# * **[The implications of embodiment for behavior and cognition: animal and robotic case studies](http://arxiv.org/abs/1202.0440v1)** (2012) <br> 👤 *Matej Hoffmann, Rolf Pfeifer*
#
# * **[A wildland fire modeling and visualization environment](http://arxiv.org/abs/1111.4610v1)** (2011) <br> 👤 *Jan Mandel, Jonathan D. Beezley, Adam K. Kochanski, Volodymyr Y. Kondratenko, Lin Zhang, Erik Anderson, Joel Daniels, Claudio T. Silva, Christopher R. Johnson*
#
# * **[Consensus in networks of mobile communicating agents](http://arxiv.org/abs/1110.2186v2)** (2011) <br> 👤 *Andrea Baronchelli, Albert Diaz-Guilera*
#
# * **[Dynamical modeling of collective behavior from pigeon flight data: flock cohesion and dispersion](http://arxiv.org/abs/1110.1739v1)** (2011) <br> 👤 *Graciano Dieck Kattas, Xiao-Ke Xu, Michael Small*
#
# * **[Synchronicity, Instant Messaging and Performance among Financial Traders](http://arxiv.org/abs/1110.0381v1)** (2011) <br> 👤 *Serguei Saavedra, Kathleen Hagerty, Brian Uzzi*
#
# * **[Role of aspiration-induced migration in cooperation](http://arxiv.org/abs/1109.0950v1)** (2011) <br> 👤 *Han-Xin Yang, Zhi-Xi Wu, Bing-Hong Wang*
#
# * **[Correlating Formal Semantic Models of Reo Connectors: Connector Coloring and Constraint Automata](http://arxiv.org/abs/1108.0468v1)** (2011) <br> 👤 *Sung-Shik T. Q. Jongmans, Farhad Arbab*
#
# * **[Monitoring wild animal communities with arrays of motion sensitive camera traps](http://arxiv.org/abs/1009.5718v1)** (2010) <br> 👤 *Roland Kays, Sameer Tilak, Bart Kranstauber, Patrick A. Jansen, Chris Carbone, Marcus J. Rowcliffe, Tony Fountain, Jay Eggert, Zhihai He*
#
# * **[Rhythm and Randomness in Human Contact](http://arxiv.org/abs/1009.3980v1)** (2010) <br> 👤 *Mervyn P. Freeman, Nicholas W. Watkins, Eiko Yoneki, Jon Crowcroft*
#
# * **[Crowded Charges in Ion Channels](http://arxiv.org/abs/1009.1786v1)** (2010) <br> 👤 *Bob Eisenberg*
#
# * **[Modular RADAR: An Immune System Inspired Search and Response Strategy for Distributed Systems](http://arxiv.org/abs/1006.3394v1)** (2010) <br> 👤 *Soumya Banerjee, Melanie Moses*
#
# * **[An Interactive Zoo Guide: A Case Study of Collaborative Learning](http://arxiv.org/abs/1006.0869v1)** (2010) <br> 👤 *Hao Shi*
#
# * **[Proviola: A Tool for Proof Re-animation](http://arxiv.org/abs/1005.2672v1)** (2010) <br> 👤 *Carst Tankink, Herman Geuvers, James McKinna, Freek Wiedijk*
#
# * **[Persistence in fluctuating environments](http://arxiv.org/abs/1005.2580v1)** (2010) <br> 👤 *Sebastian J. Schreiber, Michel Benaïm, Kolawolé A. S. Atchadé*
#
# * **[Random Convex Hulls and Extreme Value Statistics](http://arxiv.org/abs/0912.0631v1)** (2009) <br> 👤 *Satya N. Majumdar, Alain Comtet, Julien Randon-Furling*
#
# * **[The Delineation of an Interdisciplinary Specialty in terms of a Journal Set: The Case of Communication Studies](http://arxiv.org/abs/0911.1053v1)** (2009) <br> 👤 *Loet Leydesdorff, Carole Probst*
#
# * **[Self-organised complex aerial displays of thousands of starlings: a model](http://arxiv.org/abs/0908.2677v1)** (2009) <br> 👤 *H. Hildenbrandt, C. Carere, C-K. Hemelrijk*
#
# * **[Incorporating uncertainty into the study of animal social networks](http://arxiv.org/abs/0903.1519v1)** (2009) <br> 👤 *David Lusseau, Hal Whitehead, Shane Gero*
#
# * **[Animating the development of Social Networks over time using a dynamic extension of multidimensional scaling](http://arxiv.org/abs/0809.4655v1)** (2008) <br> 👤 *Loet Leydesdorff, Thomas Schank, Andrea Scharnhorst, Wouter De Nooy*
#
# * **[Derivation of evolutionary payoffs from observable behavior](http://arxiv.org/abs/0809.1138v1)** (2008) <br> 👤 *Alexander Feigel, Avraham Englander, Assaf Engel*
#
# * **[Extra-auditory effects of noise in laboratory animals: the relationship between noise and sleep](http://arxiv.org/abs/0806.1382v1)** (2008) <br> 👤 *Arnaud Rabat*
#
# * **[Modeling Context, Collaboration, and Civilization in End-User Informatics](http://arxiv.org/abs/0710.3178v1)** (2007) <br> 👤 *George A. Maney*
#
# * **[Evidence for social role in a dolphin social network](http://arxiv.org/abs/q-bio/0607048v1)** (2006) <br> 👤 *David Lusseau*
#
# * **[A Vortex Method for Bi-phasic Fluids Interacting with Rigid Bodies](http://arxiv.org/abs/math/0607597v1)** (2006) <br> 👤 *Mathieu Coquerelle, Jérémie Allard, Georges-Henri Cottet, Marie-Paule Cani*
#
# * **[Gravity's Relentless Pull: An interactive, multimedia website about black holes for Education and Public Outreach](http://arxiv.org/abs/astro-ph/0606601v1)** (2006) <br> 👤 *Roeland P. van der Marel, David Schaller, Gijs Verdoes Kleijn*
#
# * **[A simplex model for layered niche networks](http://arxiv.org/abs/physics/0603068v2)** (2006) <br> 👤 *P. Fraundorf*
#
# * **[Viscosity from Newton to Modern Non-equilibrium Statistical Mechanics](http://arxiv.org/abs/cond-mat/0601210v2)** (2006) <br> 👤 *Sebastien Viscardy*
#
# * **[Introduction to statistical physics of media processes: Mediaphysics](http://arxiv.org/abs/physics/0506217v2)** (2005) <br> 👤 *Dmitri V. Kuznetsov, Igor Mandel*
#
# * **[Social Cognitive Maps, Swarm Perception and Distributed Search on Dynamic Landscapes](http://arxiv.org/abs/nlin/0502057v1)** (2005) <br> 👤 *Vitorino Ramos, Carlos Fernandes, Agostinho C. Rosa*
#
# * **[Identifying the role that individual animals play in their social network](http://arxiv.org/abs/q-bio/0403029v1)** (2004) <br> 👤 *David Lusseau, M. E. J. Newman*
#
# * **[The emergent properties of a dolphin social network](http://arxiv.org/abs/cond-mat/0307439v1)** (2003) <br> 👤 *David Lusseau*
#
# * **[Magnetic resonance as a channel of directed transmission of electromagnetic energy in animate nature](http://arxiv.org/abs/physics/0212030v1)** (2002) <br> 👤 *E. Ya. Fursa*
#
# * **[Generating a 3D Simulation of a Car Accident from a Written Description in Natural Language: the CarSim System](http://arxiv.org/abs/cs/0105023v1)** (2001) <br> 👤 *Sylvain Dupuy, Arjan Egges, Vincent Legendre, Pierre Nugues*
#
# * **[Speech Dialogue with Facial Displays: Multimodal Human-Computer Conversation](http://arxiv.org/abs/cmp-lg/9406002v1)** (1994) <br> 👤 *Katashi Nagao, Akikazu Takeuchi*
